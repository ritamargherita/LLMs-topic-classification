# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.lines import Line2D

# %%
df = pd.read_csv('/Users/brain/Documents/GitHub/LLMs-topic-classification/results/statistics/summary_statistics_for_plots.csv')
df = df.drop(columns='dataset')

# %%
melted_df = pd.melt(df, id_vars=['context', 'system', 'softness'], 
                    var_name='countTypes', value_name='count')

# %%
# Add a dark grid
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

sns.set_context("poster")

custom_order = ["specific_terms_count", "general_terms_count", "other_terms_count", "unassigned_count", "wrong_assigned_count"]

sns.boxplot(x="countTypes",
            y="count",
            hue="system",
            data=melted_df,
            order=custom_order,
            palette="colorblind",
            flierprops=dict(marker='o', markersize=4, markerfacecolor='black'),
            width=0.4)

custom_labels = ["Specific", "General", "'Other'", "Unassigned", "Wrong"]
plt.xticks(ticks=plt.xticks()[0], labels=custom_labels)

plt.xlabel("")  # Set the name of the x-axis
plt.ylabel("Occurrence (%)")  # Set the name of the y-axis

plt.legend(loc="upper right", fontsize="small")

plt.savefig('boxplot.png')

plt.show()

# %%
df = pd.read_csv('/Users/brain/Documents/GitHub/LLMs-topic-classification/results/statistics/NeedlemanWunsch_score_formatted_for_ANOVA.csv')
df = df.drop(columns='dataset')

# %%
df
# Out:
#        setting softness        system  unassigned_count  wrong_assigned_count  \
# 0   no-context   strict       ChatGPT          0.056604              0.015094
# 1   no-context   strict       ChatGPT          0.000000              0.035714
# 2   no-context   strict       ChatGPT          0.000000              0.250000
# 3   no-context   strict       ChatGPT          0.000000              0.000000
# 4   no-context   strict       ChatGPT          0.000000              0.000000
# ..         ...      ...           ...               ...                   ...
# 95     context     soft  GoogleGemini          0.000000              0.166667
# 96     context     soft  GoogleGemini          0.000000              0.250000
# 97     context     soft  GoogleGemini          0.000000              0.088889
# 98     context     soft  GoogleGemini          0.000000              0.000000
# 99     context     soft  GoogleGemini          0.000000              0.000000
#
# ...
