# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA

# %%
df = pd.read_csv('/Users/brain/Documents/GitHub/LLMs-topic-classification/results/statistics/summary_statistics_formatted_for_MANOVA.csv')

# %%
df
# Out:
#        setting softness        system  \
# 0   no-context   strict       ChatGPT
# 1   no-context   strict       ChatGPT
# 2   no-context   strict       ChatGPT
# 3   no-context   strict       ChatGPT
# 4   no-context   strict       ChatGPT
# ..         ...      ...           ...
# 95     context     soft  GoogleGemini
# 96     context     soft  GoogleGemini
# 97     context     soft  GoogleGemini
# 98     context     soft  GoogleGemini
# 99     context     soft  GoogleGemini
#
#                                      dataset  unassigned_count  \
# 0   Education_expenditure_and_indicators.csv          0.056604
# 1                      Health_expectancy.csv          0.000000
# 2                       Listed_monuments.csv          0.000000
# 3                              Livestock.csv          0.000000
# 4       Milk_supply_and_dairy_production.csv          0.000000
# ..                                       ...               ...
# ...

# %%
# NO_CONTEXT

# %%
df_no_context = df[df["setting"]=="no-context"]

# %%
# Perform MANOVA
manova = MANOVA.from_formula('unassigned_count + wrong_assigned_count + general_terms_count + specific_terms_count + other_terms_count ~  system', data=df_no_context)

# %%
print(manova.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#        Intercept         Value  Num DF  Den DF F Value  Pr > F
# --------------------------------------------------------------
#           Wilks' lambda  0.0292 5.0000 53.0000 352.6432 0.0000
#          Pillai's trace  0.9708 5.0000 53.0000 352.6432 0.0000
#  Hotelling-Lawley trace 33.2682 5.0000 53.0000 352.6432 0.0000
#     Roy's greatest root 33.2682 5.0000 53.0000 352.6432 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#          system         Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.5260 10.0000 106.0000  4.0160 0.0001
#          Pillai's trace 0.5380 10.0000 108.0000  3.9745 0.0001
#  Hotelling-Lawley trace 0.7796 10.0000  76.8000  4.0823 0.0002
# ...

# %%
variables_list = ["unassigned_count", "wrong_assigned_count", "general_terms_count", "specific_terms_count", "other_terms_count"]

# %%
# Perform Tukey's HSD test
for variable in variables_list:
    tukey_results_system = pairwise_tukeyhsd(df_no_context[variable], df_no_context['system'])
    print(variable, tukey_results_system)
# Out:
# unassigned_count      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#    ChatGPT   GoogleBard   0.0269 0.0349  0.0016  0.0522   True
#    ChatGPT GoogleGemini  -0.0035 0.9407 -0.0288  0.0218  False
# GoogleBard GoogleGemini  -0.0304 0.0148 -0.0557 -0.0051   True
# --------------------------------------------------------------
# wrong_assigned_count      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#    ChatGPT   GoogleBard   0.0914 0.0242    0.01  0.1729   True
#    ChatGPT GoogleGemini  -0.0166 0.8764  -0.098  0.0649  False
# GoogleBard GoogleGemini   -0.108 0.0064 -0.1895 -0.0266   True
# --------------------------------------------------------------
# ...

# %%
# CONTEXT

# %%
df_context = df[df["setting"]=="context"]

# %%
# Perform MANOVA
manova = MANOVA.from_formula('unassigned_count + wrong_assigned_count + general_terms_count + specific_terms_count + other_terms_count ~  system', data=df_context)

# %%
print(manova.mv_test())
# Out:
#                   Multivariate linear model
# ...
#
# --------------------------------------------------------------
#        Intercept         Value  Num DF  Den DF F Value  Pr > F
# --------------------------------------------------------------
#           Wilks' lambda  0.0386 5.0000 34.0000 169.2018 0.0000
#          Pillai's trace  0.9614 5.0000 34.0000 169.2018 0.0000
#  Hotelling-Lawley trace 24.8826 5.0000 34.0000 169.2018 0.0000
#     Roy's greatest root 24.8826 5.0000 34.0000 169.2018 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#            system         Value  Num DF  Den DF F Value Pr > F
# --------------------------------------------------------------
#             Wilks' lambda 0.6207 5.0000 34.0000  4.1551 0.0047
#            Pillai's trace 0.3793 5.0000 34.0000  4.1551 0.0047
#    Hotelling-Lawley trace 0.6110 5.0000 34.0000  4.1551 0.0047
# ...

# %%
variables_list = ["unassigned_count", "wrong_assigned_count", "general_terms_count", "specific_terms_count", "other_terms_count"]

# %%
# Perform Tukey's HSD test
for variable in variables_list:
    tukey_results_system = pairwise_tukeyhsd(df_context[variable], df_context['system'])
    print(variable, tukey_results_system)
# Out:
# unassigned_count    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1    group2    meandiff p-adj   lower  upper  reject
# ----------------------------------------------------------
# ChatGPT GoogleGemini   0.0019 0.7578 -0.0106 0.0144  False
# ----------------------------------------------------------
# wrong_assigned_count    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1    group2    meandiff p-adj   lower  upper  reject
# ----------------------------------------------------------
# ChatGPT GoogleGemini   0.0592 0.0571 -0.0019 0.1204  False
# ----------------------------------------------------------
# general_terms_count     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1    group2    meandiff p-adj   lower   upper  reject
# -----------------------------------------------------------
# ChatGPT GoogleGemini   -0.219 0.0469 -0.4349 -0.0031   True
# -----------------------------------------------------------
# ...
